# %% [markdown]
# # MatPlotlib For Data Visualization 🎨

# %% [markdown]
# ## What Is Data Visualization?
#
# - We can visualize data and its behavior and its changes using matplotlib

# %%
import matplotlib.pyplot as plt


x = [1,2,3,4]
y = [10, 20, 15, 25]

plt.plot(x,y)

# %%
import matplotlib.pyplot as plt
import pandas as pd

x = [1,2,3,4]
y = [5,6,7,8]

plt.plot(x,y)
plt.grid()
plt.show()

# %% [markdown]
# ## MatPlotlib Terms We Should Know:
#
# 1. Data Point: simply referring to x and y axis
# 2. x-axis, y-axis: the horizontal and vertical lines on the graph used for plotting
# 3. Figure: canvas on which different graphs are made
# 4. Axes: Graph boxes, or an rectangular area where the graph is ploted
# 5. Plot: The lines, bars, shapes that are drawn in the axes
# 6. Marker: Symbol or dot used to make datapoints visible
# 7. Line Style: Customizing lines on the graph
# 8. Legend: It is a small box that shows which line and color represents what in the graph
# 9. Label: The names of x-axis and y-axis on the graph like sales/year
# 10. Grid: Horizontal and vertical lines added behind the graphs
# 11. Function: Block of codes performing a speicifc task
# 12. Method: Functions that belong to an object
# 13. Parameters: Information passed to the functions
# 14. Keyword Arguments Kwargs:
# 15. DPI Dots Per Inch: Resolution of graph controlled by dpi
# 16. Backend: TKagg is default, Qt5agg, Webagg for web apps

# %% [markdown]
# ## Understanding Basic Functions of pyplot()

# %% [markdown]
# # PyPlot API
#
# - Univariate: When we focus on one variable only like in numerical column
# - Univariate: When we focus on one variable only like in categorical column
# - Bivariate: When we focus on two variables or find their relationship

# %%
#demostrating univariate: Numerical, histograms, boxplots

import matplotlib.pyplot as plt
import pandas as pd

data = {
    "salary":[1000, 3300, 2200, 5400, 8800, 6700, 9200]
}

df = pd.DataFrame(data)
print(df)
print(df.head())


#demonstrating line plot

plt.plot(df['salary'], color="red", marker="o", linestyle=":", linewidth="2" )
plt.grid()
plt.show()


#demonstrating histogram

plt.hist(df['salary'], bins=5, color="green", edgecolor="black")
plt.show()


#demonstrating boxplot (good for identifying outliers)
#boxplot without outliers

plt.boxplot(df['salary'])
plt.show()


#boxplot with outliers
#df.loc[10] = [-10000]
#plt.boxplot(df['salary'])
#plt.show()


#demonstrating univariate: Categorical

data2 = pd.DataFrame({
    "dept": (['HR', 'IT', 'Finance', 'Sales', 'IT', 'HR', 'Sales' ])

})

print(data2)

count = data2['dept'].value_counts()
print(count)

plt.pie(count, labels=count.index, autopct='%1.1f%%', explode=[0,0.1,0.2,0], shadow=True) #explode depends on categories/labels
plt.axis('equal')
plt.show()


#demonstrating bivariate for numerical-numerical means 2 numerical columns
#using a scatter plot, we need 2 numerical columns
#using bar chart for 2 numerical columns 


data = {
    "salary":[1000, 3300, 2200, 5400, 8800, 6700, 9200]
}

df = pd.DataFrame(data)
print(df)


df['Age'] = [22, 34, 40, 19, 50, 43, 54]
df.head()

plt.scatter(df['Age'], df['salary'], color='orange')
plt.show()


plt.plot(sort_age['Age'], df['salary'], marker='*', color='red')
plt.grid()
plt.show()

sort_age = df.sort_values('Age')
print(sort_age)

plt.bar(sort_age['Age'], df['salary'], color='green')
plt.show()



#demonstrating multivariate for 3 columns
#using a bubble plot for multivariate

x = [10, 20, 30, 40]
y = [5, 15, 25, 35]
sizes = [100, 300, 600, 900]   # bubble sizes

plt.scatter(x, y, s=sizes, alpha=0.5, color='red', edgecolor='black')

plt.title("Simple Bubble Plot")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")

plt.show()
# Out:
#    salary
# 0    1000
# 1    3300
# 2    2200
# 3    5400
# 4    8800
# 5    6700
# 6    9200
#    salary
# 0    1000
# 1    3300
# 2    2200
# 3    5400
# 4    8800
#       dept
# 0       HR
# 1       IT
# 2  Finance
# 3    Sales
# 4       IT
# 5       HR
# 6    Sales
# dept
# HR         2
# IT         2
# Sales      2
# Finance    1
# Name: count, dtype: int64
#    salary
# 0    1000
# 1    3300
# 2    2200
# 3    5400
# 4    8800
# 5    6700
# 6    9200
#    salary  Age
# 3    5400   19
# 0    1000   22
# 1    3300   34
# 2    2200   40
# 5    6700   43
# 4    8800   50
# 6    9200   54

# %% [markdown]
# # Creating A Pie Chart:

# %%
import matplotlib.pyplot as plt

regions = ["North", "South", "East", "West"]
revenue  = [3000, 2000, 1500, 1000]

plt.pie(revenue, labels=regions, autopct = "%1.1f%%", colors=["green", "yellow", "red", "purple"])
plt.title("Revenue Contribution By Region")
plt.show()

# %%
import matplotlib.pyplot as plt

x = ["mon", "tues", "wed", "thurs", "fri"]
y = [10, 15, 7, 20, 12]

plt.plot(x,y)

plt.title("Bakery Sales This Week")

plt.xlabel("Days of week")
plt.ylabel("Sales per day")

plt.show()

# %%
import matplotlib.pyplot as plt

months = [1,2,3,4]
sales= [1000, 1500, 1200, 1800]
plt.plot(months, sales, color="green", linestyle="--", linewidth = 2, marker = "o", markerfacecolor="yellow", markersize=10 ,label="2025 sales data" )
plt.xlabel("Months")
plt.ylabel("Sales per month")
plt.title("Monthly Sales Data")
plt.legend() #gives a descriptive block 
plt.grid(color="purple") #displays a grid behind the graph 
plt.xticks([1,2,3,4],["M1", "M2", "M3", "M4"]) #divides x axis into parts 
plt.show()

# %% [markdown]
# ## Plotting Bar Charts, Pie Charts, and Histograms With MatPlotlib
#
# - Bar Charts: For comparing values and category analysis
#
# - Pie Charts: For proportion illustration
#
# - Histograms: For numerical data representation speically for dataspread

# %% [markdown]
# ## Creating Bar Graphs (Verical & Horizontal):

# %%
#demostrating vertical bar graphs

import matplotlib.pyplot as plt

product = ["A", "B", "C", "D", "E"]
sales = [1000, 1500, 800, 2000, 500]

plt.bar(product, sales, color="pink", label="sales")
plt.xlabel("products")
plt.ylabel("sales")
plt.title("product sale comparison")
plt.legend()
plt.show()


#demonstrating vertical bar graphs

product = ["A", "B", "C", "D", "E"]
sales = [1000, 1500, 800, 2000, 500]

plt.barh(product, sales, color="blue", label="sales")
plt.xlabel("products")
plt.ylabel("sales")
plt.title("product sale comparison")
plt.legend()
plt.show()

# %% [markdown]
# ## Creating Histograms:

# %%
import matplotlib.pyplot as plt

scores = [45, 53, 23, 15, 67, 34, 89, 82, 73, 65, 92, 80, 96, ]

plt.hist(scores, bins=5, color="magenta", edgecolor="black" )
plt.xlabel("score range")
plt.ylabel("no. of students")
plt.title("Score Distribution Of Students")
plt.show()

# %% [markdown]
# ## Creating Scatter Plots:
#
# - A graph where graphs are used to find relation between 2 data points

# %%
#handling one group in scatter plot

import matplotlib.pyplot as plt

hours_studied = [1,2,3,4,5,6,7,8]
exam_scores = [50, 55, 63, 70, 80, 85, 90, 95]

plt.scatter(hours_studied, exam_scores, color="red", marker="^", label="student data")
plt.xlabel("Hours Studied")
plt.ylabel("Exam Scores")
plt.title("Hours Studied vs Exam Scores")
plt.legend()
plt.grid(True)
plt.show()


#handling two groups in scatter plot

plt.scatter([1,2,3], [50, 55, 60], color="Orange", label="Class A")
plt.scatter([1,2,3], [45, 50, 52], color="Blue", label="Class B")

plt.xlabel("Hours Studied")
plt.ylabel("Exam Scores")
plt.title("Comparison Of Two Classes")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Object Oriented API
#
# - Commonly used for multivariate

# %% [markdown]
# ## Creating SubPlots:
#
# - Creating Parts Of Data At The Same Time

# %%
import matplotlib.pyplot as plt

x = [1,2,3,4]
y = [ 10, 20, 15, 25 ]

plt.subplot(1,2,1)
plt.plot(x,y, color="red")
plt.title("Line Chart")

plt.subplot(1,2,2)
plt.bar(x,y)
plt.title("Bar Chart")

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

x = [1,2,3,4]
y = [ 10, 20, 15, 25 ]

fig, ax = plt.subplots(1,2, figsize= (10,5))
ax[0].plot(x,y, color="green")
ax[0].set_title("Line Chart")

ax[1].bar(x,y, color="orange")
ax[1].set_title("Bar Chart")

fig.suptitle("Comparison Of Line & Bar Charts")

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y1 = [2, 4, 6, 8]
y2 = [1, 4, 9, 16]

plt.plot(x, y1, label="Line 1")
plt.plot(x, y2, label="Line 2")

plt.title("Two Plots in the Same Graph")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")

plt.legend()
plt.show()

# %% [markdown]
# ## Saving MatPlotlib Charts:

# %%
import matplotlib.pyplot as plt

x = [1,2,3,4]
y = [10, 20, 15, 25]

plt.plot(x,y, color="red", marker="o")
plt.title("simple line plot")
plt.xlabel("X Axis")
plt.xlabel("Y Axis")

plt.savefig('lineplot.png', dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# # Plotting A 3D Plot

# %%
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')  # only projection parameter

# Sample data
x = [1, 2, 3, 4]
y = [2, 4, 6, 8]
z = [1, 3, 5, 7]

ax.plot(x, y, z, marker='o', color='blue')

ax.set_xlabel("X-axis")
ax.set_ylabel("Y-axis")
ax.set_zlabel("Z-axis")
ax.set_title("3D Line Plot")

plt.show()


import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')  # only projection parameter

# Sample data
x = [1, 2, 3, 4]
y = [5, 6, 2, 3]
z = [2, 3, 3, 5]

ax.scatter(x, y, z, color='red', s=100)  # size s=100 for bubbles

ax.set_xlabel("X-axis")
ax.set_ylabel("Y-axis")
ax.set_zlabel("Z-axis")
ax.set_title("3D Scatter Plot")

plt.show()


import matplotlib.pyplot as plt
import numpy as np

# Create 3D subplot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Sample data for a cone
theta = np.linspace(0, 2*np.pi, 50)
r = np.linspace(0, 5, 50)
Theta, R = np.meshgrid(theta, r)
X = R * np.cos(Theta)
Y = R * np.sin(Theta)
Z = R  # cone shape

# Colorful surface
ax.plot_surface(X, Y, Z, cmap='rainbow')

ax.set_title("Simple Colorful 3D Cone")
plt.show()

# %%
#to rotate 3d plots, we can use plotly.express as px

import plotly.express as px
import pandas as pd

# Sample data
df = pd.DataFrame({
    "x": [1, 2, 3, 4, 5],
    "y": [5, 6, 2, 3, 1],
    "z": [2, 3, 3, 5, 4],
    "color": [10, 20, 30, 40, 50]  # optional color
})

# Create 3D scatter plot
fig = px.scatter_3d(df, x='x', y='y', z='z', color='color', size='color')

fig.show()
